# %%
import numpy as  np 
import pandas as pd

# %%
df = pd.read_csv('fortune.csv', encoding='cp1252')

# %%
df
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
sectors=df.groupby('sectors')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sectors=df.groupby('sectors')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...
